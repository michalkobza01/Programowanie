# %%
x = "Uwielbiam zajecia z programowania"

# %% [markdown]
# zadanie 1a

# %%
x[13:23]
# Out:
# 'ecia z pro'

# %% [markdown]
# zadanie 1b

# %%
x[-40:]
# Out:
# 'Uwielbiam zajecia z programowania'

# %% [markdown]
# zadanie 1c

# %%
x[1:30:3]
# Out:
# 'wlazea oaw'

# %%
y = """Czarny to mój ulubiony kolor, niestety, kolor czarny bardzo szybko
spiera się z moich ubrań"""

# %% [markdown]
# zadanie 2a

# %%
y.isupper()
# Out:
# False

# %% [markdown]
# zadanie 2b

# %%
y.startswith("C")
# Out:
# True

# %% [markdown]
# zadanie 2c

# %%
y.lower()
y = y.lower()

# %%
y.replace("czarny", "czerwony")
# Out:
# 'czerwony to mój ulubiony kolor, niestety, kolor czerwony bardzo szybko \nspiera się z moich ubrań'

# %%
y = y.replace("czarny", "czerwony")

# %%
y.capitalize()
# Out:
# 'Czerwony to mój ulubiony kolor, niestety, kolor czerwony bardzo szybko \nspiera się z moich ubrań'
